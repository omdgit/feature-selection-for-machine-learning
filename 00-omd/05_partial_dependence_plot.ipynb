# %% [markdown]
# # Partial Dependence Plots

# %%
from sklearn.datasets import load_breast_cancer, fetch_california_housing
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.inspection import PartialDependenceDisplay
import matplotlib.pyplot as plt
import seaborn as sns

# Load the breast cancer dataset
data = load_breast_cancer(as_frame=True)

# Define the features and target
X = data.data
y = data.target

# Train a GradientBoostingClassifier
clf = GradientBoostingClassifier(random_state=0)
clf.fit(X, y)

# Define the features for the partial dependence plot
features = [0, 1, (0, 1)]

# %%
# https://scikit-learn.org/stable/modules/partial_dependence.html 
PartialDependenceDisplay.from_estimator(clf, X, features)
plt.tight_layout()
plt.show()

# %%
X
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %%
X, y = fetch_california_housing(return_X_y=True, as_frame=True)
X
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# 0        -122.23
# ...

# %%
sns.boxplot(X['HouseAge']);

# %%
X['HouseAge'].plot(kind='hist', bins=15, ec='white');

# %%
df = X.copy()
df['target'] = y
df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  target
# 0    -122.23   4.526
# 1    -122.22   3.585
# 2    -122.24   3.521
# 3    -122.25   3.413
# 4    -122.25   3.422

# %%
plt.style.use('seaborn')
y.groupby(X['HouseAge']).agg(['median']).plot(kind='bar')
plt.title(f"Correlation between 'House Age' and 'Median House Value' = {np.corrcoef(X['HouseAge'], y)[0, 1]:.0%}")
plt.xlabel('House Age')
plt.ylabel('Median House Value')
plt.tight_layout()
plt.show()
# Out:
# /var/folders/5d/4vzdwckn4fqgnfhszkpm8mzm0000gn/T/ipykernel_56045/2249577384.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
import numpy as np
import pandas as pd 
from xgboost import XGBRegressor
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((14448, 8), (6192, 8), (14448,), (6192,))

# %%
model_01 = XGBRegressor(n_estimators=300, max_depth=12, learning_rate=0.1, random_state=42)
model_01.fit(X_train, y_train)

rmse_train = np.sqrt(metrics.mean_squared_error(y_train, model_01.predict(X_train)))
print(f"Root Mean Squared Error: {rmse_train}")

rmse_test = np.sqrt(metrics.mean_squared_error(y_test, model_01.predict(X_test)))
print(f"Root Mean Squared Error: {rmse_test}")
# Out:
# Root Mean Squared Error: 0.021802903128062934
# Root Mean Squared Error: 0.47707620343392027

# %%
df.corr()['target'].drop('target').sort_values().plot(kind='bar')
plt.title('Correlations with target variable "Median House Value"')
plt.xlabel('Features')
plt.ylabel('Correlation');

# %%
df_feature_importances = pd.DataFrame({'features':model_01.feature_names_in_, 'importance':model_01.feature_importances_})
df_feature_importances.sort_values(by='importance', inplace=True)
plt.bar(x=df_feature_importances.features, height=df_feature_importances.importance);

# %%
print(fetch_california_housing().DESCR)
# Out:
# .. _california_housing_dataset:
#
# California Housing dataset
# --------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 20640
#
#     :Number of Attributes: 8 numeric, predictive attributes and the target
#
#     :Attribute Information:
#         - MedInc        median income in block group
#         - HouseAge      median house age in block group
#         - AveRooms      average number of rooms per household
#         - AveBedrms     average number of bedrooms per household
#         - Population    block group population
#         - AveOccup      average number of household members
#         - Latitude      block group latitude
#         - Longitude     block group longitude
#
#     :Missing Attribute Values: None
#
# This dataset was obtained from the StatLib repository.
# https://www.dcc.fc.up.pt/~ltorgo/Regression/cal_housing.html
#
# The target variable is the median house value for California districts,
# ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor
from xgboost import XGBRegressor, XGBRFRegressor

features_01 = df_feature_importances[df_feature_importances['importance']>0.1]['features'].tolist()
model_02 = XGBRegressor(n_estimators=500, max_depth=6, learning_rate=0.1, random_state=42)
# model_02 = XGBRFRegressor(n_estimators=150, learning_rate=1.0, random_state=42)
# model_02 = XGBRegressor(random_state=42)
# model_02 = LinearRegression()
# model_02 = GradientBoostingRegressor(learning_rate=0.3, random_state=42)
# model_02 = RandomForestRegressor(random_state=42)
model_02.fit(X_train[features_01], y_train)

rmse_train = np.sqrt(metrics.mean_squared_error(y_train, model_02.predict(X_train[features_01])))
print(f"Root Mean Squared Error: {rmse_train}")

rmse_test = np.sqrt(metrics.mean_squared_error(y_test, model_02.predict(X_test[features_01])))
print(f"Root Mean Squared Error: {rmse_test}")
# Out:
# Root Mean Squared Error: 0.2814190440225981
# Root Mean Squared Error: 0.4681756454479975

# %%
from sklearn.feature_selection import mutual_info_regression

mi_ = mutual_info_regression(X_train, y_train)
df_mut_info = pd.DataFrame({'feature': X_train.columns, 'mi': mi_})
df_mut_info.sort_values(by='mi', ascending=False, inplace=True)
plt.bar(x=df_mut_info.feature, height=df_mut_info.mi)
plt.title('Mutual Information for Features')
plt.ylabel('Mututal Information')
plt.xlabel('Features')
plt.tight_layout()
plt.show()
